# %% [markdown]
# # RL model voor 2x2x2 yard
# In deze notebook wordt een RL model gemaakt voor een container yard van 2 bij 2 bij 2. Het gaat hier om een indeling waar 8 containers van 4 verschillende zeevaartschepen (die ze op komen halen) geplaatst moeten worden. Er zijn 2 containers per zeevaartschip, wat betekent dat de optimale oplossing simpel te bedenken en te checken is: Alle containers moeten dan in 1 keer gepakt kunnen worden, zoder verplaatsingen.

# %% [markdown]
# ### Imports

# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete

import random
import pandas as pd
import numpy as np
import random
import os

from IPython.display import display
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack,DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ### Functie voor reward
# Hierin worden penalty's gegeven voor slechte of niet toegestane zetten en rewards voor goede/optimale zetten. Per zet worden deze uitgedeeld, en het totaal levert de score van die 'game' op. Langzaam zou de reward steeds hoger moeten worden tijdens het trainen van het RL model.

# %%
# matrix[z_height][y_row][x_col]
def reward_functie_3D(matrix, breedte, plek, container, z_height, y_row, x_col):
    reward = 0
    
    #waar al een staat, -
    if plek !=0:
        reward -= 1
    
    #boven een lege, -
    if z_height > 0 and matrix[z_height-1][y_row][x_col] == 0:
        reward -= 1
    
    #niet twee dezelfde op begane grond, -
    if container in (matrix[z_height][0].tolist() or matrix[z_height][1].tolist()):
        reward -= 1
    
    #boven zelfde, +
    if z_height > 0 and matrix[z_height-1][y_row][x_col] == container:
        reward += 2
    
    return reward

# %% [markdown]
# ### Environment maken
# Er is hier gewerkt met als state/observation space een numpy array van 2 lijsten van 2 lijsten met 2 itemplaatsen. de eerste lijst van 2 lijsten moet de onderverdieping weergeven en de tweede de boven verdieping. links en rechts zijn de lange zijdes.

# %%
class Mijn_Env(Env):
    def __init__(self, breedte_matrix):
        self.x = breedte_matrix
        
        self.action_space = MultiDiscrete([self.x,self.x,self.x], dtype=int)
        #self.observation_space = Box(low=int(0),high=int(8),shape=(2,2,2), dtype=int)
        self.observation_space = Dict({'matrix':Box(low=int(0),high=int(8),shape=(2,2,2), dtype=int), 'container':Discrete(12)})
        self.state = np.array([[[0,0],[0,0]],[[0,0],[0,0]]])
        
        # nummers staan voor zeevaartschip waar containers voor bestemd zijn. Komen random volgorde binnen (want volgorde is onzeker)
        self.list_containers = list([1,1,2,2,3,3,4,4])
        random.shuffle(self.list_containers)
        
        # 8 te plaatsen containers
        self.duration = 8
        
    def step(self, action):
        self.duration -= 1
        container = self.list_containers.pop()
        y_row = action[0]    # 0 of 1
        x_col = action[1]    # 0 of 1
        z_height = action[2] # 0 of 1
        plek = self.state[z_height][y_row][x_col]
        
        # REWARD
        reward = reward_functie_3D(self.state, self.x, plek, container, z_height, y_row, x_col)
        
        # PLAATSEN
        self.state[z_height][y_row][x_col] = container
        
        # STOPPEN
        if self.duration <= 0:
            done=True
            obs = {'container':np.nan, 'matrix':self.state}
        else:
            done=False
            # geef mee aan model in obs: volgende te plaatsen container + huidige state van yard
            obs = {'container':self.list_containers[-1], 'matrix':self.state}
            
        info = {}
        
        return obs, reward, done, info
    
    def render(self, mode = 'human'):
        display(self.state)
    
    def reset(self):
        self.duration = 8
        self.state = np.array([[[0,0],[0,0]],[[0,0],[0,0]]])
        self.list_containers = list([1,1,2,2,3,3,4,4])
        random.shuffle(self.list_containers)

        obs = {'container':self.list_containers[-1], 'matrix':self.state}
        return obs
        #return self.state

# %%
env = Mijn_Env(2)

# %%
env.state
# Out:
# array([[[0, 0],
#         [0, 0]],
#
#        [[0, 0],
#         [0, 0]]])

# %%
print(env.list_containers)
# Out:
# [4, 1, 2, 1, 3, 2, 3, 4]

# %% [markdown]
# ### Environment testen

# %%
episodes = 2
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# array([[[0, 0],
#         [0, 0]],
#
#        [[0, 0],
#         [0, 0]]])
# array([[[0, 0],
#         [0, 0]],
#
#        [[0, 4],
#         [0, 0]]])
# array([[[0, 0],
#         [0, 1]],
#
#        [[0, 4],
#         [0, 0]]])
# array([[[0, 0],
#         [0, 1]],
#
#        [[0, 4],
#         [0, 2]]])
# array([[[0, 0],
#         [3, 1]],
#
#        [[0, 4],
#         [0, 2]]])
# array([[[0, 0],
#         [3, 1]],
#
#        [[1, 4],
#         [0, 2]]])
# array([[[0, 0],
#         [3, 1]],
#
#        [[1, 4],
#         [0, 3]]])
# array([[[0, 0],
#         [3, 1]],
#
#        [[1, 4],
#         [4, 3]]])
# Episode:1 Score:-5
# array([[[0, 0],
#         [0, 0]],
#
#        [[0, 0],
#         [0, 0]]])
# array([[[0, 0],
#         [0, 0]],
#
#        [[0, 0],
#         [2, 0]]])
# array([[[0, 0],
#         [0, 0]],
#
#        [[0, 0],
#         [2, 1]]])
# array([[[0, 0],
#         [0, 0]],
#
#        [[0, 3],
#         [2, 1]]])
# array([[[4, 0],
#         [0, 0]],
#
#        [[0, 3],
#         [2, 1]]])
# array([[[4, 0],
#         [0, 0]],
#
#        [[0, 4],
#         [2, 1]]])
# array([[[3, 0],
#         [0, 0]],
#
#        [[0, 4],
#         [2, 1]]])
# array([[[3, 2],
#         [0, 0]],
#
#        [[0, 4],
#         [2, 1]]])
# Episode:2 Score:-8

# %% [markdown]
# ### Environment trainen

# %%
model = PPO("MultiInputPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /opt/jupyterhub/anaconda/lib/python3.9/site-packages/torch/cuda/__init__.py:83: UserWarning: CUDA initialization: CUDA driver initialization failed, you might not have a CUDA gpu. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809662/work/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
time_steps=500000
model.learn(total_timesteps=int(time_steps))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8        |
# |    ep_rew_mean     | -5.61    |
# | time/              |          |
# |    fps             | 1450     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -5          |
# | time/                   |             |
# |    fps                  | 988         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014852754 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.0294      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.05        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 5.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -4.81       |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014110062 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0306     |
# |    value_loss           | 3.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -4          |
# | time/                   |             |
# |    fps                  | 898         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017021682 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.283       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.949       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -4.18       |
# | time/                   |             |
# |    fps                  | 883         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012997033 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 2.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -3.64       |
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012644161 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.976       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 2.21        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8         |
# |    ep_rew_mean          | -3.6      |
# | time/                   |           |
# |    fps                  | 862       |
# |    iterations           | 7         |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0124528 |
# |    clip_fraction        | 0.129     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.88     |
# |    explained_variance   | 0.247     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.48      |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.0156   |
# |    value_loss           | 2.4       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -3.86       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012031674 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -3.66       |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010392696 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -3.55       |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010966573 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 2.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -3.38       |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 11          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010452728 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 2.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -3.41       |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 12          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010112464 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -3.27       |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 13          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013274277 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 2.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -2.97       |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013077777 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 2.57        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | -3.15      |
# | time/                   |            |
# |    fps                  | 783        |
# |    iterations           | 15         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01271226 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.174      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.15       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0195    |
# |    value_loss           | 2.52       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -3.01       |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 16          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011775134 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -2.66       |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 17          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012514406 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -2.67       |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 18          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011602678 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -2.32       |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 19          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010519103 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0851      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -2.06       |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 20          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012632292 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | -2.22      |
# | time/                   |            |
# |    fps                  | 793        |
# |    iterations           | 21         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01167076 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.122      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.13       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.018     |
# |    value_loss           | 2.68       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -2.06       |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 22          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011199093 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.063       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 2.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -2.07       |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 23          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011766195 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.073       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 2.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -1.73       |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 24          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009741524 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.067       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 2.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -1.57       |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 25          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010015497 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0599      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 2.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -1.43       |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 26          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013056311 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | 0.0882      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 2.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -1.24       |
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 27          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012150679 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.0715      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 2.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -1.33       |
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 28          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011403028 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.883      |
# |    explained_variance   | 0.0729      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 2.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -0.79       |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 29          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013065681 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | 0.0596      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -0.87       |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 30          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010738509 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.0765      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -1.29       |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 31          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007577729 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | 0.0206      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -0.45       |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 32          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010247231 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.741      |
# |    explained_variance   | 0.0711      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 2.43        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | -0.59      |
# | time/                   |            |
# |    fps                  | 789        |
# |    iterations           | 33         |
# |    time_elapsed         | 85         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01088538 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.688     |
# |    explained_variance   | 0.0599     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.51       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0164    |
# |    value_loss           | 2.66       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | -0.02      |
# | time/                   |            |
# |    fps                  | 789        |
# |    iterations           | 34         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00862808 |
# |    clip_fraction        | 0.0801     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.664     |
# |    explained_variance   | 0.0931     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.32       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 2.66       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -0.24       |
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 35          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008136608 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 3.13        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -0.4         |
# | time/                   |              |
# |    fps                  | 788          |
# |    iterations           | 36           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0068605337 |
# |    clip_fraction        | 0.0789       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0.0715       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0136      |
# |    value_loss           | 2.86         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 37          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008244167 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 2.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 0.63        |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 38          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008880097 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 3.11        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 0.27         |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 39           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0074366755 |
# |    clip_fraction        | 0.0759       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 2.9          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 0.7          |
# | time/                   |              |
# |    fps                  | 791          |
# |    iterations           | 40           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0061268965 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 3.06         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 0.52        |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 41          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007720964 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 3.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 42          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008237114 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.479      |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.85        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 43          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008065093 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.456      |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 3           |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 0.93         |
# | time/                   |              |
# |    fps                  | 794          |
# |    iterations           | 44           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0091213025 |
# |    clip_fraction        | 0.0917       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.43        |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 2.87         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 1.16        |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 45          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.012645302 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.415      |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 1.66         |
# | time/                   |              |
# |    fps                  | 793          |
# |    iterations           | 46           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0080802925 |
# |    clip_fraction        | 0.0847       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.402       |
# |    explained_variance   | 0.322        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0146      |
# |    value_loss           | 2.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 2.58         |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 47           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0058077304 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 0.326        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 2.75         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 1.84        |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 48          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008300973 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.347      |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 2.25        |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 49          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005866848 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.348      |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.928       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 1.5          |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 50           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0076941755 |
# |    clip_fraction        | 0.0739       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.335       |
# |    explained_variance   | 0.426        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 2.36         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 2.57        |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 51          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007777087 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.321      |
# |    explained_variance   | 0.425       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 2.57        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 2.65        |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 52          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008150709 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.285      |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.662       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 2           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 2.63        |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 53          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.005850629 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.276      |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.935       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 2.08        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 3.13         |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 54           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0075576436 |
# |    clip_fraction        | 0.0582       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | 0.49         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.568        |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0133      |
# |    value_loss           | 1.84         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 3.24        |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 55          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.006884125 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6         |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 2.21        |
# ...
# |    value_loss           | 1.06         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 5.71        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 228         |
# |    time_elapsed         | 599         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.009893829 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0522     |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.578       |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 1.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 5.32        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 229         |
# |    time_elapsed         | 602         |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.005606746 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0575     |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.386       |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 5.59        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 230         |
# |    time_elapsed         | 605         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.004917655 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0558     |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.453       |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 0.99        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 5.73        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 231         |
# |    time_elapsed         | 607         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.009832844 |
# |    clip_fraction        | 0.0207      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.057      |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.44        |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00207    |
# |    value_loss           | 1.01        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 5.57         |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 232          |
# |    time_elapsed         | 610          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0042045955 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0605      |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.469        |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.000944    |
# |    value_loss           | 0.948        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 5.56         |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 233          |
# |    time_elapsed         | 613          |
# |    total_timesteps      | 477184       |
# | train/                  |              |
# |    approx_kl            | 0.0058917515 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.06        |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.42         |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 0.929        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 5.56        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 234         |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.014695408 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0737     |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.365       |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 0.997       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 6.03        |
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 235         |
# |    time_elapsed         | 618         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.013981496 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0829     |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.454       |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 1.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 5.71        |
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 236         |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.006882243 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.076      |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.868       |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.0028     |
# |    value_loss           | 1.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 5.42         |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 237          |
# |    time_elapsed         | 624          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0072311964 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0745      |
# |    explained_variance   | 0.759        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.468        |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 1.02         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | 5.72       |
# | time/                   |            |
# |    fps                  | 777        |
# |    iterations           | 238        |
# |    time_elapsed         | 627        |
# |    total_timesteps      | 487424     |
# | train/                  |            |
# |    approx_kl            | 0.00639935 |
# |    clip_fraction        | 0.0272     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.074     |
# |    explained_variance   | 0.756      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.518      |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.0021    |
# |    value_loss           | 1.03       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | 5.69         |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 239          |
# |    time_elapsed         | 629          |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0045311553 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0696      |
# |    explained_variance   | 0.76         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.331        |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 1.01         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 5.84        |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 240         |
# |    time_elapsed         | 632         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.008024539 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0643     |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.549       |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00337    |
# |    value_loss           | 1.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 5.98        |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 241         |
# |    time_elapsed         | 635         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.007363688 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0623     |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.484       |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.006      |
# |    value_loss           | 1.05        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | 5.87       |
# | time/                   |            |
# |    fps                  | 776        |
# |    iterations           | 242        |
# |    time_elapsed         | 638        |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.00985308 |
# |    clip_fraction        | 0.0245     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.068     |
# |    explained_variance   | 0.727      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.538      |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.00455   |
# |    value_loss           | 1.15       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | 5.89       |
# | time/                   |            |
# |    fps                  | 776        |
# |    iterations           | 243        |
# |    time_elapsed         | 641        |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.01961809 |
# |    clip_fraction        | 0.0363     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0697    |
# |    explained_variance   | 0.762      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.556      |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.00485   |
# |    value_loss           | 1.16       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | 5.71        |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 244         |
# |    time_elapsed         | 644         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.012804093 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0639     |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.769       |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 1.12        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | 6.01       |
# | time/                   |            |
# |    fps                  | 775        |
# |    iterations           | 245        |
# |    time_elapsed         | 646        |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.01090218 |
# |    clip_fraction        | 0.031      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0574    |
# |    explained_variance   | 0.756      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.44       |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | -0.00519   |
# |    value_loss           | 1.07       |
# ----------------------------------------

# %% [markdown]
# ### Model gebruiken/evalueren

# %%
# from stable_baselines3.common.monitor import Monitor
# env.reset()
# monitor = Monitor(env)
evaluate_policy(model, env, n_eval_episodes=1, return_episode_rewards = True, render=True)
# Out:
# /opt/jupyterhub/anaconda/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# array([[[0, 0],
#         [0, 4]],
#
#        [[0, 0],
#         [0, 0]]])
# array([[[0, 3],
#         [0, 4]],
#
#        [[0, 0],
#         [0, 0]]])
# array([[[0, 3],
#         [0, 4]],
#
#        [[0, 0],
#         [0, 4]]])
# array([[[0, 3],
#         [0, 4]],
#
#        [[0, 3],
#         [0, 4]]])
# array([[[1, 3],
#         [0, 4]],
#
#        [[0, 3],
#         [0, 4]]])
# array([[[1, 3],
#         [2, 4]],
#
#        [[0, 3],
#         [0, 4]]])
# array([[[1, 3],
#         [2, 4]],
#
#        [[0, 3],
#         [2, 4]]])
# array([[[0, 0],
#         [0, 0]],
#
#        [[0, 0],
#         [0, 0]]])
# ([8.0], [8])

# %% [markdown]
# # Conclusie
# In het testvoorbeeld is te zien dat de optimale indeling gevonden is. Er staan in elke hoek 2 containers voor zelfde schip op elkaar, dus het maakt niet uit welk schip nu aankomt: de stacker kan bij de conatainers zonder dat die andere containers hoeft de verplaatsen.
